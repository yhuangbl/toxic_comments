# %%
from utils import max_features, maxlen, embed_size_fastText, embed_size_glove, embed_size_glove_twitter
from utils import batch_size, epochs, run_5fold_2channels
from model import get_multiChannel_CNN_model
import pickle
import pandas as pd
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ec2-user/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ec2-user/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
fastText = pickle.load(open("input/fastText.300d.pickle", "rb"))
glove = pickle.load(open("input/glove.300d.pickle", "rb"))
glove_twitter = pickle.load(open("input/glove.twitter.200d.pickle", "rb"))

# %%
x_train = pickle.load(open("input/x_train.pickle", "rb"))
y_train = pickle.load(open("input/y_train.pickle", "rb"))
x_test = pickle.load(open("input/x_test.pickle", "rb"))
submission = pd.read_csv("input/sample_submission.csv")

# %% [markdown]
# ### baseline performance
#
# - glove
# loss: 0.04493380877026916 (+/- 0.0008816936950137447)
#
# - twitter
# loss: 0.045302061441733474 (+/- 0.0007931266631046235)

# %%
params = {
    "maxlen": maxlen,
    "max_features": max_features,
    "embed_size1": embed_size_glove_twitter,
    "embedding_matrix1": glove_twitter,
    "dropout1": 0.2,
    "num_filter1": 50,
    "kernel_size1": 3,
    "reg1": 0,
    "embed_size2": embed_size_glove,
    "embedding_matrix2": glove,
    "dropout2": 0.2,
    "num_filter2": 300,
    "kernel_size2": 3,
    "reg2": 0
}

# %% [markdown]
# ## check dense_units

# %%
units = [64, 128, 256, 512, 768]

# %%
predictions = {}

# %%
for u in units:
    print ("\n********************u:{}********************".format(u))
    params["dense_units"] = u
    predictions[u] = run_5fold_2channels([x_train, x_train], y_train, x_test, "loss", get_multiChannel_CNN_model, **params)
# Out:
# ********************u:64********************
# WARNING:tensorflow:From /home/ec2-user/toxic_comments/model.py:33: streaming_auc (from tensorflow.contrib.metrics.python.ops.metric_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.metrics.auc. Note that the order of the labels and predictions arguments has been switched.
# Train on 127656 samples, validate on 31915 samples
# Epoch 1/50
#  - 75s - loss: 0.0550 - acc: 0.9803 - auc_roc: 0.9452 - val_loss: 0.0500 - val_acc: 0.9808 - val_auc_roc: 0.9778
# Epoch 2/50
#  - 74s - loss: 0.0389 - acc: 0.9851 - auc_roc: 0.9819 - val_loss: 0.0436 - val_acc: 0.9831 - val_auc_roc: 0.9840
# Epoch 3/50
#  - 74s - loss: 0.0318 - acc: 0.9877 - auc_roc: 0.9859 - val_loss: 0.0487 - val_acc: 0.9823 - val_auc_roc: 0.9869
# Epoch 00003: early stopping
# val loss: 0.048687142019205175
# val acc: 0.9822601495109605
# val auc roc: 0.9869381492309355
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0533 - acc: 0.9810 - auc_roc: 0.9536 - val_loss: 0.0497 - val_acc: 0.9813 - val_auc_roc: 0.9791
# Epoch 2/50
#  - 74s - loss: 0.0394 - acc: 0.9849 - auc_roc: 0.9827 - val_loss: 0.0444 - val_acc: 0.9834 - val_auc_roc: 0.9844
# Epoch 3/50
#  - 74s - loss: 0.0320 - acc: 0.9876 - auc_roc: 0.9860 - val_loss: 0.0504 - val_acc: 0.9814 - val_auc_roc: 0.9870
# Epoch 00003: early stopping
# val loss: 0.05038010536038712
# val acc: 0.9814135633614933
# val auc roc: 0.9870065743592835
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0544 - acc: 0.9808 - auc_roc: 0.9441 - val_loss: 0.0447 - val_acc: 0.9834 - val_auc_roc: 0.9774
# Epoch 2/50
#  - 74s - loss: 0.0395 - acc: 0.9848 - auc_roc: 0.9814 - val_loss: 0.0437 - val_acc: 0.9835 - val_auc_roc: 0.9838
# Epoch 3/50
#  - 74s - loss: 0.0322 - acc: 0.9874 - auc_roc: 0.9856 - val_loss: 0.0452 - val_acc: 0.9836 - val_auc_roc: 0.9867
# Epoch 00003: early stopping
# val loss: 0.04517201700627135
# val acc: 0.9835547385691192
# val auc roc: 0.9866921757930068
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0539 - acc: 0.9811 - auc_roc: 0.9515 - val_loss: 0.0437 - val_acc: 0.9832 - val_auc_roc: 0.9788
# Epoch 2/50
#  - 74s - loss: 0.0395 - acc: 0.9848 - auc_roc: 0.9825 - val_loss: 0.0446 - val_acc: 0.9833 - val_auc_roc: 0.9845
# Epoch 00002: early stopping
# val loss: 0.04463020847356132
# val acc: 0.9833354009470038
# val auc roc: 0.9844727110704354
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0553 - acc: 0.9804 - auc_roc: 0.9421 - val_loss: 0.0452 - val_acc: 0.9829 - val_auc_roc: 0.9770
# Epoch 2/50
#  - 74s - loss: 0.0394 - acc: 0.9847 - auc_roc: 0.9815 - val_loss: 0.0456 - val_acc: 0.9827 - val_auc_roc: 0.9836
# Epoch 00002: early stopping
# val loss: 0.045589420183379005
# val acc: 0.9826617132245041
# val auc roc: 0.9836026566282747
#
#
# ********************u:128********************
# Train on 127656 samples, validate on 31915 samples
# Epoch 1/50
#  - 74s - loss: 0.0570 - acc: 0.9800 - auc_roc: 0.9297 - val_loss: 0.0475 - val_acc: 0.9820 - val_auc_roc: 0.9746
# Epoch 2/50
#  - 74s - loss: 0.0401 - acc: 0.9846 - auc_roc: 0.9799 - val_loss: 0.0450 - val_acc: 0.9827 - val_auc_roc: 0.9825
# Epoch 3/50
#  - 74s - loss: 0.0326 - acc: 0.9875 - auc_roc: 0.9846 - val_loss: 0.0471 - val_acc: 0.9828 - val_auc_roc: 0.9858
# Epoch 00003: early stopping
# val loss: 0.04710699222128667
# val acc: 0.9827980378849575
# val auc roc: 0.9857802904345073
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0553 - acc: 0.9806 - auc_roc: 0.9363 - val_loss: 0.0442 - val_acc: 0.9831 - val_auc_roc: 0.9760
# Epoch 2/50
#  - 74s - loss: 0.0398 - acc: 0.9847 - auc_roc: 0.9806 - val_loss: 0.0447 - val_acc: 0.9830 - val_auc_roc: 0.9830
# Epoch 00002: early stopping
# val loss: 0.044676034195183914
# val acc: 0.9830481714381157
# val auc roc: 0.9830401808858299
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0543 - acc: 0.9806 - auc_roc: 0.9465 - val_loss: 0.0434 - val_acc: 0.9838 - val_auc_roc: 0.9775
# Epoch 2/50
#  - 74s - loss: 0.0398 - acc: 0.9847 - auc_roc: 0.9815 - val_loss: 0.0450 - val_acc: 0.9831 - val_auc_roc: 0.9837
# Epoch 00002: early stopping
# val loss: 0.04499047090804106
# val acc: 0.9831265043762608
# val auc roc: 0.9837022368423979
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0545 - acc: 0.9809 - auc_roc: 0.9487 - val_loss: 0.0442 - val_acc: 0.9832 - val_auc_roc: 0.9778
# Epoch 2/50
#  - 74s - loss: 0.0400 - acc: 0.9846 - auc_roc: 0.9818 - val_loss: 0.0438 - val_acc: 0.9837 - val_auc_roc: 0.9836
# Epoch 3/50
#  - 74s - loss: 0.0323 - acc: 0.9875 - auc_roc: 0.9854 - val_loss: 0.0469 - val_acc: 0.9825 - val_auc_roc: 0.9865
# Epoch 00003: early stopping
# val loss: 0.046940788158820884
# val acc: 0.9824998199233751
# val auc roc: 0.986474435969075
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0572 - acc: 0.9801 - auc_roc: 0.9353 - val_loss: 0.0446 - val_acc: 0.9830 - val_auc_roc: 0.9754
# Epoch 2/50
#  - 74s - loss: 0.0394 - acc: 0.9848 - auc_roc: 0.9805 - val_loss: 0.0456 - val_acc: 0.9828 - val_auc_roc: 0.9829
# Epoch 00002: early stopping
# val loss: 0.0456074466268737
# val acc: 0.9827766081194176
# val auc roc: 0.9829484042184816
#
#
# ********************u:256********************
# Train on 127656 samples, validate on 31915 samples
# Epoch 1/50
#  - 74s - loss: 0.0607 - acc: 0.9807 - auc_roc: 0.9408 - val_loss: 0.0460 - val_acc: 0.9824 - val_auc_roc: 0.9720
# Epoch 2/50
#  - 74s - loss: 0.0402 - acc: 0.9847 - auc_roc: 0.9777 - val_loss: 0.0443 - val_acc: 0.9829 - val_auc_roc: 0.9809
# Epoch 3/50
#  - 74s - loss: 0.0328 - acc: 0.9874 - auc_roc: 0.9833 - val_loss: 0.0471 - val_acc: 0.9827 - val_auc_roc: 0.9846
# Epoch 00003: early stopping
# val loss: 0.047121770854221694
# val acc: 0.9826883687170699
# val auc roc: 0.9846394228651365
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0547 - acc: 0.9807 - auc_roc: 0.9491 - val_loss: 0.0464 - val_acc: 0.9824 - val_auc_roc: 0.9773
# Epoch 2/50
#  - 74s - loss: 0.0401 - acc: 0.9846 - auc_roc: 0.9814 - val_loss: 0.0445 - val_acc: 0.9832 - val_auc_roc: 0.9835
# Epoch 3/50
#  - 74s - loss: 0.0327 - acc: 0.9875 - auc_roc: 0.9852 - val_loss: 0.0481 - val_acc: 0.9828 - val_auc_roc: 0.9861
# Epoch 00003: early stopping
# val loss: 0.04813703336743788
# val acc: 0.9828131663333863
# val auc roc: 0.9860865225982881
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0567 - acc: 0.9806 - auc_roc: 0.9475 - val_loss: 0.0442 - val_acc: 0.9831 - val_auc_roc: 0.9762
# Epoch 2/50
#  - 74s - loss: 0.0402 - acc: 0.9847 - auc_roc: 0.9806 - val_loss: 0.0455 - val_acc: 0.9837 - val_auc_roc: 0.9825
# Epoch 00002: early stopping
# val loss: 0.04547372183577417
# val acc: 0.9836696357351127
# val auc roc: 0.9825443530460718
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0561 - acc: 0.9803 - auc_roc: 0.9393 - val_loss: 0.0449 - val_acc: 0.9828 - val_auc_roc: 0.9757
# Epoch 2/50
#  - 74s - loss: 0.0408 - acc: 0.9844 - auc_roc: 0.9800 - val_loss: 0.0467 - val_acc: 0.9825 - val_auc_roc: 0.9823
# Epoch 00002: early stopping
# val loss: 0.046705885889099574
# val acc: 0.9824737051327127
# val auc roc: 0.9822540152728083
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 74s - loss: 0.0559 - acc: 0.9807 - auc_roc: 0.9517 - val_loss: 0.0470 - val_acc: 0.9824 - val_auc_roc: 0.9760
# Epoch 2/50
#  - 74s - loss: 0.0405 - acc: 0.9845 - auc_roc: 0.9802 - val_loss: 0.0543 - val_acc: 0.9799 - val_auc_roc: 0.9824
# Epoch 00002: early stopping
# val loss: 0.05430851804200267
# val acc: 0.9799199708461194
# val auc roc: 0.9824098595111914
#
#
# ********************u:512********************
# Train on 127656 samples, validate on 31915 samples
# Epoch 1/50
#  - 75s - loss: 0.0566 - acc: 0.9805 - auc_roc: 0.9367 - val_loss: 0.0454 - val_acc: 0.9827 - val_auc_roc: 0.9745
# Epoch 2/50
#  - 74s - loss: 0.0406 - acc: 0.9847 - auc_roc: 0.9792 - val_loss: 0.0472 - val_acc: 0.9823 - val_auc_roc: 0.9817
# Epoch 00002: early stopping
# val loss: 0.04717880944970464
# val acc: 0.9822549282673402
# val auc roc: 0.9817351291345127
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 75s - loss: 0.0561 - acc: 0.9805 - auc_roc: 0.9356 - val_loss: 0.0447 - val_acc: 0.9830 - val_auc_roc: 0.9747
# Epoch 2/50
#  - 74s - loss: 0.0402 - acc: 0.9846 - auc_roc: 0.9796 - val_loss: 0.0448 - val_acc: 0.9834 - val_auc_roc: 0.9822
# Epoch 00002: early stopping
# val loss: 0.04481672462078984
# val acc: 0.9833824001114911
# val auc roc: 0.9821944838068632
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 75s - loss: 0.0570 - acc: 0.9803 - auc_roc: 0.9381 - val_loss: 0.0476 - val_acc: 0.9825 - val_auc_roc: 0.9746
# Epoch 2/50
#  - 74s - loss: 0.0407 - acc: 0.9845 - auc_roc: 0.9796 - val_loss: 0.0437 - val_acc: 0.9836 - val_auc_roc: 0.9821
# Epoch 3/50
#  - 74s - loss: 0.0339 - acc: 0.9870 - auc_roc: 0.9841 - val_loss: 0.0471 - val_acc: 0.9826 - val_auc_roc: 0.9853
# Epoch 00003: early stopping
# val loss: 0.04706477169702695
# val acc: 0.982640825783974
# val auc roc: 0.9852896808957877
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 75s - loss: 0.0557 - acc: 0.9804 - auc_roc: 0.9392 - val_loss: 0.0450 - val_acc: 0.9826 - val_auc_roc: 0.9756
# Epoch 2/50
#  - 74s - loss: 0.0406 - acc: 0.9845 - auc_roc: 0.9803 - val_loss: 0.0450 - val_acc: 0.9831 - val_auc_roc: 0.9825
# Epoch 3/50
#  - 74s - loss: 0.0332 - acc: 0.9871 - auc_roc: 0.9845 - val_loss: 0.0476 - val_acc: 0.9825 - val_auc_roc: 0.9856
# Epoch 00003: early stopping
# val loss: 0.04759896980600787
# val acc: 0.9825311511047145
# val auc roc: 0.9856440258547575
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 75s - loss: 0.0560 - acc: 0.9806 - auc_roc: 0.9475 - val_loss: 0.0470 - val_acc: 0.9822 - val_auc_roc: 0.9766
# Epoch 2/50
#  - 74s - loss: 0.0404 - acc: 0.9844 - auc_roc: 0.9810 - val_loss: 0.0462 - val_acc: 0.9823 - val_auc_roc: 0.9832
# Epoch 3/50
#  - 74s - loss: 0.0332 - acc: 0.9871 - auc_roc: 0.9851 - val_loss: 0.0473 - val_acc: 0.9830 - val_auc_roc: 0.9861
# Epoch 00003: early stopping
# val loss: 0.04726699995669688
# val acc: 0.9830063902592908
# val auc roc: 0.986093764769939
#
#
# ********************u:768********************
# Train on 127656 samples, validate on 31915 samples
# Epoch 1/50
#  - 75s - loss: 0.0561 - acc: 0.9805 - auc_roc: 0.9425 - val_loss: 0.0454 - val_acc: 0.9825 - val_auc_roc: 0.9753
# Epoch 2/50
#  - 74s - loss: 0.0407 - acc: 0.9846 - auc_roc: 0.9801 - val_loss: 0.0453 - val_acc: 0.9827 - val_auc_roc: 0.9824
# Epoch 3/50
#  - 74s - loss: 0.0335 - acc: 0.9871 - auc_roc: 0.9844 - val_loss: 0.0471 - val_acc: 0.9829 - val_auc_roc: 0.9856
# Epoch 00003: early stopping
# val loss: 0.04706046737983797
# val acc: 0.9829077006768381
# val auc roc: 0.9855776686849927
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 75s - loss: 0.0568 - acc: 0.9805 - auc_roc: 0.9404 - val_loss: 0.0498 - val_acc: 0.9813 - val_auc_roc: 0.9747
# Epoch 2/50
#  - 74s - loss: 0.0406 - acc: 0.9845 - auc_roc: 0.9793 - val_loss: 0.0445 - val_acc: 0.9833 - val_auc_roc: 0.9818
# Epoch 3/50
#  - 74s - loss: 0.0336 - acc: 0.9870 - auc_roc: 0.9838 - val_loss: 0.0497 - val_acc: 0.9827 - val_auc_roc: 0.9848
# Epoch 00003: early stopping
# val loss: 0.04968827649691376
# val acc: 0.9826826091927903
# val auc roc: 0.9848038498983427
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 75s - loss: 0.0574 - acc: 0.9802 - auc_roc: 0.9457 - val_loss: 0.0510 - val_acc: 0.9812 - val_auc_roc: 0.9752
# Epoch 2/50
#  - 74s - loss: 0.0409 - acc: 0.9845 - auc_roc: 0.9797 - val_loss: 0.0467 - val_acc: 0.9834 - val_auc_roc: 0.9816
# Epoch 3/50
#  - 74s - loss: 0.0337 - acc: 0.9869 - auc_roc: 0.9833 - val_loss: 0.0483 - val_acc: 0.9828 - val_auc_roc: 0.9846
# Epoch 00003: early stopping
# val loss: 0.04830188811256778
# val acc: 0.9828131610553665
# val auc roc: 0.9845881086098951
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 75s - loss: 0.0563 - acc: 0.9801 - auc_roc: 0.9415 - val_loss: 0.0452 - val_acc: 0.9830 - val_auc_roc: 0.9751
# Epoch 2/50
#  - 74s - loss: 0.0407 - acc: 0.9845 - auc_roc: 0.9797 - val_loss: 0.0468 - val_acc: 0.9821 - val_auc_roc: 0.9822
# Epoch 00002: early stopping
# val loss: 0.04680220065853788
# val acc: 0.9821238117856909
# val auc roc: 0.9821599610857238
#
# Train on 127657 samples, validate on 31914 samples
# Epoch 1/50
#  - 75s - loss: 0.0567 - acc: 0.9804 - auc_roc: 0.9471 - val_loss: 0.0456 - val_acc: 0.9828 - val_auc_roc: 0.9759
# Epoch 2/50
#  - 74s - loss: 0.0406 - acc: 0.9845 - auc_roc: 0.9804 - val_loss: 0.0493 - val_acc: 0.9815 - val_auc_roc: 0.9826
# Epoch 00002: early stopping
# val loss: 0.04930019018436319
# val acc: 0.9814501234468619
# val auc roc: 0.9825875200319538

# %%
from utils import eval_results

# %%
eval_results(predictions)
# Out:
# key: 64
# loss: 0.046891778608560794 (+/- 0.0022432195708695342)
# acc: 0.9826451131226162 (+/- 0.0007705975724367511)
# roc_auc: 0.9857424534163872 (+/- 0.0014227184367519052)
#
#
#
# key: 128
# loss: 0.04586434642204125 (+/- 0.0009944483156291547)
# acc: 0.9828498283484253 (+/- 0.0002220085391398572)
# roc_auc: 0.9843891096700583 (+/- 0.0014595208143253504)
#
#
#
# key: 256
# loss: 0.0483493859977072 (+/- 0.0030994813850276845)
# acc: 0.9823129693528803 (+/- 0.0012636410264706636)
# roc_auc: 0.9835868346586993 (+/- 0.001523471539188107)
#
#
#
# key: 512
# loss: 0.04678525510604523 (+/- 0.0010002336258586515)
# acc: 0.9827631391053622 (+/- 0.00039235508267792814)
# roc_auc: 0.984191416892372 (+/- 0.0018415360633717952)
#
#
#
# key: 768
# loss: 0.04823060456644411 (+/- 0.001156154051542159)
# acc: 0.9823954812315095 (+/- 0.0005453023547289084)
# roc_auc: 0.9839434216621816 (+/- 0.0013301069280577487)

# %% [markdown]
# ##### result
#
# - 64:
#
# - 128:
#
#
#
# - 256:
#
#
#
# - 512:
#
#
#
# - 768:

# %%
params = {
    "maxlen": maxlen,
    "max_features": max_features,
    "embed_size1": embed_size_fastText,
    "embedding_matrix1": fastText,
    "dropout1": 0.1,
    "num_filter1": 500,
    "kernel_size1": 9,
    "reg1": 0,
    "embed_size2": embed_size_glove,
    "embedding_matrix2": glove,
    "dropout2": 0.2,
    "num_filter2": 500,
    "kernel_size2": 7,
    "reg2": 0,
    "dense_units": 768
}
