# %%
from utils import max_features, maxlen, embed_size_fastText, embed_size_glove, embed_size_glove_twitter
from utils import earlystop, batch_size, epochs, run_5fold_2channels
from model import get_multiChannel_CNN_model
import pickle
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ec2-user/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ec2-user/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# ...

# %%
fastText = pickle.load(open("input/fastText.300d.pickle", "rb"))
glove = pickle.load(open("input/glove.300d.pickle", "rb"))

# %%
x_train = pickle.load(open("input/x_train_small.pickle", "rb"))
y_train = pickle.load(open("input/y_train_small.pickle", "rb"))

# %% [markdown]
# ### baseline performance
#
# - fastText single layer
#
# acc: 97.7272242339% (+/- 0.0262575199%)
#
# roc_auc: 99.3181312003% (+/- 0.0253788972%)
#
# - glove single layer
#
# acc: 97.7449803026% (+/- 0.0835450620%)
#
# roc_auc: 99.3592604342% (+/- 0.0654025651%)

# %%
params = {
    "maxlen": maxlen,
    "max_features": max_features,
    "embed_size1": embed_size_fastText,
    "embedding_matrix1": fastText,
    "dropout1": 0.1,
    "num_filter1": 500,
    "kernel_size1": 9,
    "reg1": 0,
    "embed_size2": embed_size_glove,
    "embedding_matrix2": glove,
    "dropout2": 0.2,
    "num_filter2": 500,
    "kernel_size2": 7,
    "reg2": 0
}

# %% [markdown]
# ## check dense_units

# %%
units = [128, 256, 512, 768]

# %%
for u in units:
    print ("\n********************u:{}********************".format(u))
    params["dense_units"] = u
    run_5fold_2channels([x_train, x_train], y_train, get_multiChannel_CNN_model, **params)
# Out:
# ********************u:128********************
# WARNING:tensorflow:From /home/ec2-user/toxic_comments/model.py:33: streaming_auc (from tensorflow.contrib.metrics.python.ops.metric_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.metrics.auc. Note that the order of the labels and predictions arguments has been switched.
# Epoch 1/50
#  - 24s - loss: 0.1516 - acc: 0.9614 - auc_roc: 0.7348
# Epoch 2/50
#  - 22s - loss: 0.0667 - acc: 0.9802 - auc_roc: 0.8638
# Epoch 3/50
#  - 22s - loss: 0.0333 - acc: 0.9912 - auc_roc: 0.9189
# Epoch 4/50
#  - 22s - loss: 0.0189 - acc: 0.9966 - auc_roc: 0.9464
# Epoch 5/50
#  - 22s - loss: 0.0138 - acc: 0.9984 - auc_roc: 0.9607
# Epoch 6/50
#  - 22s - loss: 0.0109 - acc: 0.9991 - auc_roc: 0.9689
# Epoch 7/50
#  - 22s - loss: 0.0103 - acc: 0.9992 - auc_roc: 0.9740
# Epoch 8/50
#  - 22s - loss: 0.0097 - acc: 0.9993 - auc_roc: 0.9775
# Epoch 9/50
# ...

# %% [markdown]
# ##### result
#
# - 128:
#
# acc: 97.7460335099% (+/- 0.1470031126%)
#
# roc_auc: 97.5354285869% (+/- 4.1264994645%)
#
# - 256:
#
# acc: 97.4942727921% (+/- 0.7053694075%)
#
# roc_auc: 92.2276879419% (+/- 11.2570677909%)
#
# - 512:
#
# acc: 97.7585674088% (+/- 0.1304108819%)
#
# roc_auc: 99.5166337291% (+/- 0.1620516927%)
#
# - 768:
#
# acc: 97.7648326617% (+/- 0.1258659665%)
#
# roc_auc: 99.5579392558% (+/- 0.0663592110%)

# %%
params = {
    "maxlen": maxlen,
    "max_features": max_features,
    "embed_size1": embed_size_fastText,
    "embedding_matrix1": fastText,
    "dropout1": 0.1,
    "num_filter1": 500,
    "kernel_size1": 9,
    "reg1": 0,
    "embed_size2": embed_size_glove,
    "embedding_matrix2": glove,
    "dropout2": 0.2,
    "num_filter2": 500,
    "kernel_size2": 7,
    "reg2": 0,
    "dense_units": 768
}
